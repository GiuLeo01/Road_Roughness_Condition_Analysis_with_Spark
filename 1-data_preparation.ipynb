# %%
from pyspark.sql.types import *
import pyspark.sql.functions as F
from pyspark.sql.window import *
from functions import *
from pyspark.sql import SparkSession
import pandas as pd
import numpy as np
from pyspark.ml.feature import VectorAssembler, StringIndexer
from pyspark.ml.stat import Correlation

# %%
spark = SparkSession.builder \
   .master("local") \
   .appName("DataPreparation") \
   .config("spark.executor.memory", "8gb") \
   .getOrCreate()

sc = spark.sparkContext

# %%
# preparo tutti i dataset e li metto in un dizionario per un accesso più comodo
dataset = {name:dataset_preparation(name, spark, 'data') for name in [f'PVS{i+1}' for i in range(9)]}

# %%
def get_structural_features(data, window_size:int=200):
    """
    Funzione che, a partire dai dati di un driving process, restituisce la rappresentazione strutturale delle time series estratte dal dataset applicando una sliding window.
    Per ogni variabile originale, le statistiche  strutturali calcolate sono la media e la deviazione standard
    """
    # piuttosto che materializzare le time series e poi calcolare le feature strutturali, calcolo direttamente le feature strutturali con la window, così risparmio moltissima memoria
    padding = data.filter(data['timestep'] == data.count()-1) # prendo l'ultimo elemento
    data = data.union(padding) # lo duplico alla fine del dataset, per poter calcolare la deviazione standard anche per l'ultima finestra (altrimenti darebbe errore)
    cols = data.columns

    # la sliding window
    window = Window.orderBy("timestep").rowsBetween(0, window_size)

    # le funzioni aggregative che rappresentato le features strutturali
    features = [F.avg(col).over(window).alias(f'avg_{col}') for col in cols[1:-1]]\
        + [F.std(col).over(window).alias(f'std_{col}') for col in cols[3:-1]]


    data_proc = data.select(
        'timestep',
        *features,
        F.mode('road_condition').over(window).alias(f'road_condition')
    )

    data_proc = data_proc.dropDuplicates(subset=['timestep']) # rimuovo il record che si era formato alla fine per il padding

    return data_proc

# %%
pvs1_proc = get_structural_features(dataset['PVS1'])
pvs7_proc = get_structural_features(dataset['PVS7'])

# %%
# unisco PVS1 e PVS7
pvs_proc = pvs1_proc.union(pvs7_proc)

# %%
pvs_proc.show(5)
# Out:
# +--------+-------------------+-------------------+--------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------+----------------------+----------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+--------------------+---------------------------+---------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------+----------------------+----------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+--------------------+---------------------------+---------------------------+--------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------+----------------------+----------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+--------------------+---------------------------+---------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------+----------------------+----------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+--------------------+---------------------------+---------------------------+--------------+
# |timestep|       avg_latitude|      avg_longitude|           avg_speed|avg_acc_x_dashboard_L|avg_acc_y_dashboard_L|avg_acc_z_dashboard_L|avg_acc_x_above_suspension_L|avg_acc_y_above_suspension_L|avg_acc_z_above_suspension_L|avg_acc_x_below_suspension_L|avg_acc_y_below_suspension_L|avg_acc_z_below_suspension_L|avg_gyro_x_dashboard_L|avg_gyro_y_dashboard_L|avg_gyro_z_dashboard_L|avg_gyro_x_above_suspension_L|avg_gyro_y_above_suspension_L|avg_gyro_z_above_suspension_L|avg_gyro_x_below_suspension_L|avg_gyro_y_below_suspension_L|avg_gyro_z_below_suspension_L|avg_mag_x_dashboard_L|avg_mag_y_dashboard_L|avg_mag_z_dashboard_L|avg_mag_x_above_suspension_L|avg_mag_y_above_suspension_L|avg_mag_z_above_suspension_L|avg_temp_dashboard_L|avg_temp_above_suspension_L|avg_temp_below_suspension_L|avg_acc_x_dashboard_R|avg_acc_y_dashboard_R|avg_acc_z_dashboard_R|avg_acc_x_above_suspension_R|avg_acc_y_above_suspension_R|avg_acc_z_above_suspension_R|avg_acc_x_below_suspension_R|avg_acc_y_below_suspension_R|avg_acc_z_below_suspension_R|avg_gyro_x_dashboard_R|avg_gyro_y_dashboard_R|avg_gyro_z_dashboard_R|avg_gyro_x_above_suspension_R|avg_gyro_y_above_suspension_R|avg_gyro_z_above_suspension_R|avg_gyro_x_below_suspension_R|avg_gyro_y_below_suspension_R|avg_gyro_z_below_suspension_R|avg_mag_x_dashboard_R|avg_mag_y_dashboard_R|avg_mag_z_dashboard_R|avg_mag_x_above_suspension_R|avg_mag_y_above_suspension_R|avg_mag_z_above_suspension_R|avg_temp_dashboard_R|avg_temp_above_suspension_R|avg_temp_below_suspension_R|           std_speed|std_acc_x_dashboard_L|std_acc_y_dashboard_L|std_acc_z_dashboard_L|std_acc_x_above_suspension_L|std_acc_y_above_suspension_L|std_acc_z_above_suspension_L|std_acc_x_below_suspension_L|std_acc_y_below_suspension_L|std_acc_z_below_suspension_L|std_gyro_x_dashboard_L|std_gyro_y_dashboard_L|std_gyro_z_dashboard_L|std_gyro_x_above_suspension_L|std_gyro_y_above_suspension_L|std_gyro_z_above_suspension_L|std_gyro_x_below_suspension_L|std_gyro_y_below_suspension_L|std_gyro_z_below_suspension_L|std_mag_x_dashboard_L|std_mag_y_dashboard_L|std_mag_z_dashboard_L|std_mag_x_above_suspension_L|std_mag_y_above_suspension_L|std_mag_z_above_suspension_L|std_temp_dashboard_L|std_temp_above_suspension_L|std_temp_below_suspension_L|std_acc_x_dashboard_R|std_acc_y_dashboard_R|std_acc_z_dashboard_R|std_acc_x_above_suspension_R|std_acc_y_above_suspension_R|std_acc_z_above_suspension_R|std_acc_x_below_suspension_R|std_acc_y_below_suspension_R|std_acc_z_below_suspension_R|std_gyro_x_dashboard_R|std_gyro_y_dashboard_R|std_gyro_z_dashboard_R|std_gyro_x_above_suspension_R|std_gyro_y_above_suspension_R|std_gyro_z_above_suspension_R|std_gyro_x_below_suspension_R|std_gyro_y_below_suspension_R|std_gyro_z_below_suspension_R|std_mag_x_dashboard_R|std_mag_y_dashboard_R|std_mag_z_dashboard_R|std_mag_x_above_suspension_R|std_mag_y_above_suspension_R|std_mag_z_above_suspension_R|std_temp_dashboard_R|std_temp_above_suspension_R|std_temp_below_suspension_R|road_condition|
# +--------+-------------------+-------------------+--------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------+----------------------+----------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+--------------------+---------------------------+---------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------+----------------------+----------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+--------------------+---------------------------+---------------------------+--------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------+----------------------+----------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+--------------------+---------------------------+---------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------+----------------------+----------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+--------------------+---------------------------+---------------------------+--------------+
# |       0| -27.71784097471324| -51.09886521077202|0.009213722097014891|    0.362870444651741|  0.16713105855154156|    9.783270203887783|         0.33874539843655205|         0.19070131440812382|           9.767174434403849|         0.01655436449952367|         0.19958401962963462|           9.813954271944716|  -0.04537971458624845|  0.018467120270230907|  -0.03582778854749689|         0.023966723167698312|          0.08260594772896214|          -0.0531382098416072|         -0.02166270870813...|         -0.00441658979794...|         -0.02550180702236591|   23.264638642022547|   -5.880076292327531|   1.7722716279712514|           74.92967348135483|           -8.20252152951158|         -3.5855202608997794|   34.99704684413322|          33.28267265821429|          31.73638606023405|  0.30541585831978924|   0.1656787548828116|    9.843155917378134|           0.307609010665
853469|           9.901672148099927|  0.035678806589610534|   0.06974727953251321|  0.027572100435323457|         0.021613377590894614|          0.08608412213181424|         -0.03726840265137719|         0.028901157441640814|         -0.01315170230687265|         -0.10093186263565979|   21.420236061787385|   -5.874087995576612|   2.1231570812333636|          117.99798483543829|          14.143036769902425|         -13.033478153350032|   34.32731913559469|          33.97969969841093|         31.742227401942547|1.397462273904606...|  0.02308171205556016|  0.02130498669023489|  0.03536241682769809|        0.022600278747542127|        0.023913470169203192|        0.041350603213910195|        0.020358743998166662|        0.020405127496660125|        0.035335812755239546|   0.13158000701366399|    0.1453150150474462|    0.1262716597965268|          0.11804996559659223|           0.1266722303443364|          0.14188204355409229|           0.1218865563022998|           0.1383506940563426|           0.6193360330985969|   0.7756680356369305|   0.7347389209135271|   0.6205370533263281|          0.5501449972835948|          1.7613499842655334|           1.310005413965411| 0.09519677174361184|        0.09659113694455526|        0.15873420386544163|  0.02015838122533243|  0.02259719328618069|  0.03660724245961613|        0.021648316699010496|        0.020389449021076388|          0.0399840592903465|        0.020921909886967842|         0.05463483173878598|        0.036067337756490216|    0.1445383604500353|   0.14102982996144967|   0.14311552607652445|          0.13851633143475048|           0.1446378627436083|          0.12591462439000553|          0.12985916316230717|           0.5674413713251278|          0.12547055967866552|   0.6266981156964411|   0.8445562756229372|   0.7564891935654061|            2.92739300872332|          0.5450231945247858|          2.8898055024963663| 0.08917448228032464|        0.11690713292953543|         0.1296272379540685|          good|
# +--------+-------------------+-------------------+--------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------+----------------------+----------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+--------------------+---------------------------+---------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------+----------------------+----------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+--------------------+---------------------------+---------------------------+--------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------+----------------------+----------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+--------------------+---------------------------+---------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------+----------------------+----------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+--------------------+---------------------------+---------------------------+--------------+
# only showing top 5 rows

# %%
pvs_proc.count()
# Out:
# 272584

# %%
# vettorizzo i dati
assembler = VectorAssembler(inputCols=pvs_proc.columns[3:-1], outputCol='features')
pvs_proc_vect = assembler.transform(pvs_proc)

# %%
# creao una colonna label con la label numerica
indexer = StringIndexer(inputCol="road_condition", outputCol="label", handleInvalid="skip")
pvs_proc_vect = pvs_proc_vect.select('timestep', 'features', 'road_condition')
pvs_proc_vect = indexer.fit(pvs_proc_vect).transform(pvs_proc_vect)

# %% [markdown]
# # Feature Selection

# %% [markdown]
# Ora faccio il processo di feature selection, analizzando la correlazione tra le feature, per un campione dei dati che comprende PVS1 e PVS7, ho scelto questi due driving process perchè entrambi appartenenti allo scenario 1 (ho preferito evitare di mischiare insieme informazioni da più scenari); ho escluso PVS4 perchè i dati del guidatore 2 successivamente li userò per il test set della classificazione, quindi non voglio toccarli in nessuna analisi.

# %%
# calcolo la correlation matrix tra le features
matrix = Correlation.corr(pvs_proc_vect.select('features'), 'features')

# %%
# la matrice è solo 110x110, quindi posso fare collect
corr_matrix = matrix.collect()[0][0].toArray().tolist() 
corr_matrix_df = pd.DataFrame(data=corr_matrix, columns=pvs1_proc.columns[3:-1], index=pvs1_proc.columns[3:-1])

# %%
corr_matrix_df.shape
# Out:
# (110, 110)

# %% [markdown]
# ## correlation matrix pre features selection (Sconsiglio di visualizzarla perchè troppo grande)

# %%
#corr_matrix_df.style.background_gradient(cmap='coolwarm')

# %% [markdown]
# ## Correlation Feature Selection

# %%
# stampo tutte le coppie di feature con correlazione assolut >= 0.75, poi sceglierò arbitrariamente quali tenere
# scorro solo gli elementi sopra la diagonale principale tanto la matrice è simmetrica
z = 0
for i in range(corr_matrix_df.shape[0]):
    for j in range(0+z, corr_matrix_df.shape[1]):
        if abs(corr_matrix_df.iloc[i,j]) >= 0.75 and i!=j:
            print(corr_matrix_df.columns[i], corr_matrix_df.columns[j], corr_matrix_df.iloc[i,j])
    z += 1
# Out:
# avg_acc_x_dashboard_L avg_acc_x_above_suspension_L 0.9817201870053519
# avg_acc_x_dashboard_L avg_acc_x_below_suspension_L 0.9182939800492064
# avg_acc_x_dashboard_L avg_acc_x_dashboard_R 0.9590750242048502
# avg_acc_x_dashboard_L avg_acc_x_above_suspension_R 0.9289181800277347
# avg_acc_x_dashboard_L avg_acc_x_below_suspension_R 0.9203889498122404
# avg_acc_y_dashboard_L avg_acc_y_above_suspension_L 0.9815718749149694
# avg_acc_y_dashboard_L avg_acc_y_below_suspension_L 0.9326025890901657
# avg_acc_y_dashboard_L avg_acc_y_dashboard_R 0.980995450486379
# avg_acc_y_dashboard_L avg_acc_y_above_suspension_R 0.9753539894584256
# avg_acc_y_dashboard_L avg_acc_y_below_suspension_R 0.9151238880701226
# avg_acc_x_above_suspension_L avg_acc_x_below_suspension_L 0.8977312740038976
# avg_acc_x_above_suspension_L avg_acc_x_dashboard_R 0.9486922075337724
# avg_acc_x_above_suspension_L avg_acc_x_above_suspension_R 0.926451993927171
# avg_acc_x_above_suspension_L avg_acc_x_below_suspension_R 0.8985559422832139
# avg_acc_y_above_suspension_L avg_acc_y_below_suspension_L 0.9256809468244326
# avg_acc_y_above_suspension_L avg_acc_y_dashboard_R 0.9796430059012441
# avg_acc_y_above_suspension_L avg_acc_y_above_suspension_R 0.9691545545182092
# avg_acc_y_above_suspension_L avg_acc_y_below_suspension_R 0.9005207368373164
# avg_acc_x_below_suspension_L avg_acc_x_dashboard_R 0.9029181773952144
# avg_acc_x_below_suspension_L avg_acc_x_above_suspension_R 0.8369054047284429
# avg_acc_x_below_suspension_L avg_acc_x_below_suspension_R 0.8374984737491844
# avg_acc_y_below_suspension_L avg_acc_y_dashboard_R 0.9366411390697723
# avg_acc_y_below_suspension_L avg_acc_y_above_suspension_R 0.9320848675811667
# avg_acc_y_below_suspension_L avg_acc_y_below_suspension_R 0.8740839747716224
# avg_gyro_x_dashboard_L avg_gyro_x_dashboard_R 0.8318347820506159
# avg_gyro_x_dashboard_L avg_gyro_x_above_suspension_R 0.8662531476240932
# avg_gyro_y_dashboard_L avg_gyro_y_above_suspension_L 0.9127497498414375
# avg_gyro_y_dashboard_L avg_gyro_y_dashboard_R 0.9066466079943958
# avg_gyro_z_dashboard_L avg_gyro_z_above_suspension_L 0.9986685903454084
# avg_gyro_z_dashboard_L avg_gyro_z_below_suspension_L 0.9953882792390957
# avg_gyro_z_dashboard_L avg_gyro_z_dashboard_R 0.9974483473028848
# avg_gyro_z_dashboard_L avg_gyro_z_above_suspension_R 0.9969172116998867
# avg_gyro_z_dashboard_L avg_gyro_z_below_suspension_R 0.9879272775699238
# avg_gyro_y_above_suspension_L avg_gyro_y_dashboard_R 0.8223174270583811
# avg_gyro_z_above_suspension_L avg_gyro_z_below_suspension_L 0.9949637743587494
# avg_gyro_z_above_suspension_L avg_gyro_z_dashboard_R 0.9961364535989746
# avg_gyro_z_above_suspension_L avg_gyro_z_above_suspension_R 0.996031865832778
# avg_gyro_z_above_suspension_L avg_gyro_z_below_suspension_R 0.986996225016133
# avg_gyro_z_below_suspension_L avg_gyro_z_dashboard_R 0.9921538287679407
# avg_gyro_z_below_suspension_L avg_gyro_z_above_suspension_R 0.9918373217875823
# avg_gyro_z_below_suspension_L avg_gyro_z_below_suspension_R 0.9812177353517201
# avg_mag_x_dashboard_L avg_mag_x_dashboard_R 0.9958291625222632
# avg_mag_y_dashboard_L avg_mag_y_dashboard_R 0.9985035068268857
# avg_mag_z_dashboard_L avg_mag_z_dashboard_R 0.9052375312455516
# avg_mag_y_above_suspension_L avg_mag_z_above_suspension_R 0.8024857908892508
# avg_mag_y_above_suspension_L std_mag_z_above_suspension_L 0.7737369708367715
# avg_mag_y_above_suspension_L std_mag_x_above_suspension_R -0.7704724010288604
# avg_mag_z_above_suspension_L std_mag_z_above_suspension_L -0.9481680739427533
# avg_temp_dashboard_L avg_temp_dashboard_R 0.9786291079668051
# avg_temp_above_suspension_L avg_temp_above_suspension_R 0.8161947746983065
# avg_temp_below_suspension_L avg_temp_below_suspension_R 0.9804761258817151
# avg_acc_x_dashboard_R avg_acc_x_above_suspension_R 0.961973730059259
# avg_acc_x_dashboard_R avg_acc_x_below_suspension_R 0.8963909255184876
# avg_acc_y_dashboard_R avg_acc_y_above_suspension_R 0.9786091907348152
# avg_acc_y_dashboard_R avg_acc_y_below_suspension_R 0.9195502110737398
# avg_acc_x_above_suspension_R avg_acc_x_below_suspension_R 0.8296364143677679
# avg_acc_y_above_suspension_R avg_acc_y_below_suspension_R 0.887351376073981
# avg_gyro_x_dashboard_R avg_gyro_x_above_suspension_R 0.9117153099001917
# avg_gyro_z_dashboard_R avg_gyro_z_above_suspension_R 0.9991591694196076
# avg_gyro_z_dashboard_R avg_gyro_z_below_suspension_R 0.9924296509004795
# avg_gyro_z_above_suspension_R avg_gyro_z_below_suspension_R 0.9917933422449234
# avg_mag_z_above_suspension_R std_mag_x_above_suspension_R -0.8162950240252018
# avg_temp_dashboard_R avg_temp_below_suspension_R -0.779175404557169
# std_acc_x_dashboard_L std_acc_y_dashboard_L 0.9076025557229751
# std_acc_x_dashboard_L std_acc_z_dashboard_L 0.8528209390583643
# std_acc_x_dashboard_L std_acc_z_above_suspension_L 0.7583442923572615
# std_acc_x_dashboard_L std_acc_x_below_suspension_L 0.8473837048883566
# std_acc_x_dashboard_L std_acc_y_below_suspension_L 0.8423609822081791
# std_acc_x_dashboard_L std_acc_z_below_suspension_L 0.8339667802380775
# std_acc_x_dashboard_L std_gyro_x_dashboard_L 0.8482617187050059
# std_acc_x_dashboard_L std_gyro_y_dashboard_L 0.9249550187244565
# std_acc_x_dashboard_L std_gyro_y_below_suspension_L 0.8010708797164937
# std_acc_x_dashboard_L std_gyro_z_below_suspension_L 0.8817399522732688
# std_acc_x_dashboard_L std_acc_x_dashboard_R 0.9867136407752759
# std_acc_x_dashboard_L std_acc_y_dashboard_R 0.8991599806988592
# std_acc_x_dashboard_L std_acc_z_dashboard_R 0.8573708769493827
# std_acc_x_dashboard_L std_acc_x_above_suspension_R 0.7617258549011012
# std_acc_x_dashboard_L std_acc_y_above_suspension_R 0.7802333263815824
# std_acc_x_dashboard_L std_acc_z_above_suspension_R 0.8259444856532976
# std_acc_x_dashboard_L std_acc_x_below_suspension_R 0.8352481438845768
# std_acc_x_dashboard_L std_acc_y_below_suspension_R 0.8789041924514721
# std_acc_x_dashboard_L std_acc_z_below_suspension_R 0.7966014381708626
# std_acc_x_dashboard_L std_gyro_y_dashboard_R 0.9479225387140991
# std_acc_x_dashboard_L std_gyro_z_below_suspension_R 0.8888039913790197
# std_acc_y_dashboard_L std_acc_z_dashboard_L 0.9125836046278443
# std_acc_y_dashboard_L std_acc_y_above_suspension_L 0.8445218308977238
# std_acc_y_dashboard_L std_acc_z_above_suspension_L 0.8138891327305542
# std_acc_y_dashboard_L std_acc_x_below_suspension_L 0.8871060454671218
# std_acc_y_dashboard_L std_acc_y_below_suspension_L 0.9192212750755416
# std_acc_y_dashboard_L std_acc_z_below_suspension_L 0.7692693850739998
# std_acc_y_dashboard_L std_gyro_x_dashboard_L 0.8978726531026792
# std_acc_y_dashboard_L std_gyro_y_dashboard_L 0.8346903915193943
# std_acc_y_dashboard_L std_gyro_z_below_suspension_L 0.839042415891311
# std_acc_y_dashboard_L std_acc_x_dashboard_R 0.9025681166461018
# std_acc_y_dashboard_L std_acc_y_dashboard_R 0.9928327286951961
# std_acc_y_dashboard_L std_acc_z_dashboard_R 0.9137183957979572
# std_acc_y_dashboard_L std_acc_x_above_suspension_R 0.8063233052768003
# std_acc_y_dashboard_L std_acc_y_above_suspension_R 0.8831485626323919
# std_acc_y_dashboard_L std_acc_z_above_suspension_R 0.8641837998157291
# std_acc_y_dashboard_L std_acc_x_below_suspension_R 0.876517110342096
# std_acc_y_dashboard_L std_acc_y_below_suspension_R 0.9403279339635803
# std_acc_y_dashboard_L std_gyro_x_dashboard_R 0.8295493786769277
# std_acc_y_dashboard_L std_gyro_y_dashboard_R 0.9466423543777799
# std_acc_y_dashboard_L std_gyro_z_below_suspension_R 0.8424948002531282
# std_acc_z_dashboard_L std_acc_x_above_suspension_L 0.8878794516319518
# std_acc_z_dashboard_L std_acc_y_above_suspension_L 0.9075348129523684
# std_acc_z_dashboard_L std_acc_z_above_suspension_L 0.9451874326073879
# std_acc_z_dashboard_L std_acc_x_below_suspension_L 0.944855531040691
# std_acc_z_dashboard_L std_acc_y_below_suspension_L 0.9430025393041598
# std_acc_z_dashboard_L std_gyro_x_dashboard_L 0.8821397802559826
# std_acc_z_dashboard_L std_gyro_x_above_suspension_L 0.7722545935492713
# std_acc_z_dashboard_L std_gyro_y_below_suspension_L 0.7528485483621558
# std_acc_z_dashboard_L std_acc_x_dashboard_R 0.8517696131529694
# std_acc_z_dashboard_L std_acc_y_dashboard_R 0.9083970418207257
# std_acc_z_dashboard_L std_acc_z_dashboard_R 0.9874714665609231
# std_acc_z_dashboard_L std_acc_x_above_suspension_R 0.8987096882242815
# std_acc_z_dashboard_L std_acc_y_above_suspension_R 0.9093476197593104
# std_acc_z_dashboard_L std_acc_z_above_suspension_R 0.94886295894765
# std_acc_z_dashboard_L std_acc_x_below_suspension_R 0.9258425196197515
# std_acc_z_dashboard_L std_acc_y_below_suspension_R 0.9247987674915491
# std_acc_z_dashboard_L std_gyro_x_dashboard_R 0.9179091993208681
# std_acc_z_dashboard_L std_gyro_y_dashboard_R 0.8948200103277024
# std_acc_x_above_suspension_L std_acc_y_above_suspension_L 0.9465870755775517
# std_acc_x_above_suspension_L std_acc_z_above_suspension_L 0.9619699032518673
# std_acc_x_above_suspension_L std_acc_x_below_suspension_L 0.8932385110049977
# std_acc_x_above_suspension_L std_acc_y_below_suspension_L 0.8782944154743647
# std_acc_x_above_suspension_L std_gyro_y_above_suspension_L 0.8996958298938347
# std_acc_x_above_suspension_L std_acc_z_dashboard_R 0.8671394663477078
# std_acc_x_above_suspension_L std_acc_x_above_suspension_R 0.9372458867980502
# std_acc_x_above_suspension_L std_acc_y_above_suspension_R 0.8900753001018566
# std_acc_x_above_suspension_L std_acc_z_above_suspension_R 0.8874785430907163
# std_acc_x_above_suspension_L std_acc_x_below_suspension_R 0.8766966491003083
# std_acc_x_above_suspension_L std_acc_y_below_suspension_R 0.8115474895375568
# std_acc_x_above_suspension_L std_gyro_x_dashboard_R 0.9072076207101138
# std_acc_y_above_suspension_L std_acc_z_above_suspension_L 0.9488972338333805
# std_acc_y_above_suspension_L std_acc_x_below_suspension_L 0.8909609129523771
# std_acc_y_above_suspension_L std_acc_y_below_suspension_L 0.9121673753746624
# std_acc_y_above_suspension_L std_gyro_x_dashboard_L 0.8030370996442106
# std_acc_y_above_suspension_L std_gyro_x_above_suspension_L 0.7591591314567004
# std_acc_y_above_suspension_L std_gyro_y_above_suspension_L 0.8283642703240506
# std_acc_y_above_suspension_L std_acc_y_dashboard_R 0.8445076003847571
# std_acc_y_above_suspension_L std_acc_z_dashboard_R 0.8876312357381331
# std_acc_y_above_suspension_L std_acc_x_above_suspension_R 0.9416929553150922
# std_acc_y_above_suspension_L std_acc_y_above_suspension_R 0.9466291803441778
# std_acc_y_above_suspension_L std_acc_z_above_suspension_R 0.9091784040600688
# std_acc_y_above_suspension_L std_acc_x_below_suspension_R 0.8775330484255196
# std_acc_y_above_suspension_L std_acc_y_below_suspension_R 0.8574489323605451
# std_acc_y_above_suspension_L std_gyro_x_dashboard_R 0.9378055892989964
# std_acc_y_above_suspension_L std_gyro_y_dashboard_R 0.784827656474704
# std_acc_z_above_suspension_L std_acc_x_below_suspension_L 0.9221633315732466
# std_acc_z_above_suspension_L std_acc_y_below_suspension_L 0.9109315163639807
# std_acc_z_above_suspension_L std_gyro_x_dashboard_L 0.8099630584511917
# std_acc_z_above_suspension_L std_gyro_x_above_suspension_L 0.8020781171659106
# std_acc_z_above_suspension_L std_gyro_y_above_suspension_L 0.8644076786068623
# std_acc_z_above_suspension_L std_acc_x_dashboard_R 0.7601379153679674
# std_acc_z_above_suspension_L std_acc_y_dashboard_R 0.8132982292771535
# std_acc_z_above_suspension_L std_acc_z_dashboard_R 0.9310769498186884
# std_acc_z_above_suspension_L std_acc_x_above_suspension_R 0.9364444696096038
# std_acc_z_above_suspension_L std_acc_y_above_suspension_R 0.9146312222397573
# std_acc_z_above_suspension_L std_acc_z_above_suspension_R 0.9410422807498443
# std_acc_z_above_suspension_L std_acc_x_below_suspension_R 0.9032580495113033
# std_acc_z_above_suspension_L std_acc_y_below_suspension_R 0.8605516873797863
# std_acc_z_above_suspension_L std_gyro_x_dashboard_R 0.9368299295329119
# std_acc_z_above_suspension_L std_gyro_y_dashboard_R 0.7916615515441562
# std_acc_x_below_suspension_L std_acc_y_below_suspension_L 0.9496700414620206
# std_acc_x_below_suspension_L std_gyro_x_dashboard_L 0.8132479686630971
# std_acc_x_below_suspension_L std_acc_x_dashboard_R 0.8455332144421958
# std_acc_x_below_suspension_L std_acc_y_dashboard_R 0.8845062204227788
# std_acc_x_below_suspension_L std_acc_z_dashboard_R 0.9385107800452648
# std_acc_x_below_suspension_L std_acc_x_above_suspension_R 0.8883845647571863
# std_acc_x_below_suspension_L std_acc_y_above_suspension_R 0.8857882990221754
# std_acc_x_below_suspension_L std_acc_z_above_suspension_R 0.9142372998707057
# std_acc_x_below_suspension_L std_acc_x_below_suspension_R 0.9586801397880459
# std_acc_x_below_suspension_L std_acc_y_below_suspension_R 0.9287729381641866
# std_acc_x_below_suspension_L std_gyro_x_dashboard_R 0.859684666132402
# std_acc_x_below_suspension_L std_gyro_y_dashboard_R 0.8798894490231788
# std_acc_y_below_suspension_L std_gyro_x_dashboard_L 0.8382639003017779
# std_acc_y_below_suspension_L std_acc_x_dashboard_R 0.8397824373547855
# std_acc_y_below_suspension_L std_acc_y_dashboard_R 0.9166506753968316
# std_acc_y_below_suspension_L std_acc_z_dashboard_R 0.9339651966776112
# std_acc_y_below_suspension_L std_acc_x_above_suspension_R 0.8856093752323417
# std_acc_y_below_suspension_L std_acc_y_above_suspension_R 0.9072238798156381
# std_acc_y_below_suspension_L std_acc_z_above_suspension_R 0.9048881898394447
# std_acc_y_below_suspension_L std_acc_x_below_suspension_R 0.9422042269725949
# std_acc_y_below_suspension_L std_acc_y_below_suspension_R 0.9546016873953798
# std_acc_y_below_suspension_L std_gyro_x_dashboard_R 0.8889451812527016
# std_acc_y_below_suspension_L std_gyro_y_dashboard_R 0.8811408034264341
# std_acc_z_below_suspension_L std_gyro_y_dashboard_L 0.8201074226125347
# std_acc_z_below_suspension_L std_gyro_y_below_suspension_L 0.8821782406756458
# std_acc_z_below_suspension_L std_gyro_z_below_suspension_L 0.8639030848188542
# std_acc_z_below_suspension_L std_acc_x_dashboard_R 0.8251177420883812
# std_acc_z_below_suspension_L std_acc_y_dashboard_R 0.7610400910555549
# std_acc_z_below_suspension_L std_acc_z_below_suspension_R 0.9053117574507498
# std_acc_z_below_suspension_L std_gyro_y_dashboard_R 0.8161834784722738
# std_acc_z_below_suspension_L std_gyro_z_below_suspension_R 0.806058949097838
# std_gyro_x_dashboard_L std_gyro_y_dashboard_L 0.7849529604261807
# std_gyro_x_dashboard_L std_gyro_x_above_suspension_L 0.8195535730506057
# std_gyro_x_dashboard_L std_gyro_z_below_suspension_L 0.7521102055605066
# std_gyro_x_dashboard_L std_acc_x_dashboard_R 0.8439384631373871
# std_gyro_x_dashboard_L std_acc_y_dashboard_R 0.889629252691045
# std_gyro_x_dashboard_L std_acc_z_dashboard_R 0.8768019668086319
# std_gyro_x_dashboard_L std_acc_x_above_suspension_R 0.7866173233248874
# std_gyro_x_dashboard_L std_acc_y_above_suspension_R 0.8364255454682609
# std_gyro_x_dashboard_L std_acc_z_above_suspension_R 0.8600257477255955
# std_gyro_x_dashboard_L std_acc_x_below_suspension_R 0.7972971288207361
# std_gyro_x_dashboard_L std_acc_y_below_suspension_R 0.8405559842428406
# std_gyro_x_dashboard_L std_gyro_x_dashboard_R 0.8772186876961326
# std_gyro_x_dashboard_L std_gyro_y_dashboard_R 0.858002205688434
# std_gyro_x_dashboard_L std_gyro_z_below_suspension_R 0.7624378622236443
# std_gyro_y_dashboard_L std_gyro_y_below_suspension_L 0.7567093218136651
# std_gyro_y_dashboard_L std_gyro_z_below_suspension_L 0.8559874675451022
# std_gyro_y_dashboard_L std_acc_x_dashboard_R 0.9149774247262187
# std_gyro_y_dashboard_L std_acc_y_dashboard_R 0.8229049459571033
# std_gyro_y_dashboard_L std_acc_y_below_suspension_R 0.7768974149296553
# std_gyro_y_dashboard_L std_acc_z_below_suspension_R 0.813764093655092
# std_gyro_y_dashboard_L std_gyro_y_dashboard_R 0.9011186658619259
# std_gyro_y_dashboard_L std_gyro_z_below_suspension_R 0.8664899512780011
# std_gyro_z_dashboard_L std_gyro_z_above_suspension_L 0.9510386357322289
# std_gyro_z_dashboard_L std_gyro_z_dashboard_R 0.9810778311490549
# std_gyro_z_dashboard_L std_gyro_z_above_suspension_R 0.9446577207339133
# std_gyro_x_above_suspension_L std_gyro_y_above_suspension_L 0.8247643372442498
# std_gyro_x_above_suspension_L std_acc_z_dashboard_R 0.7563524085856715
# std_gyro_x_above_suspension_L std_acc_x_above_suspension_R 0.750032236297687
# std_gyro_x_above_suspension_L std_acc_z_above_suspension_R 0.7816955446819137
# std_gyro_x_above_suspension_L std_gyro_x_dashboard_R 0.8495945609449256
# std_gyro_x_above_suspension_L std_gyro_x_above_suspension_R 0.7999687711123742
# std_gyro_y_above_suspension_L std_acc_x_above_suspension_R 0.838924659816708
# std_gyro_y_above_suspension_L std_acc_y_above_suspension_R 0.7526626714477708
# std_gyro_y_above_suspension_L std_acc_z_above_suspension_R 0.7723620933194904
# std_gyro_y_above_suspension_L std_gyro_x_dashboard_R 0.8236303526583801
# std_gyro_z_above_suspension_L std_gyro_z_dashboard_R 0.9692119581882354
# std_gyro_z_above_suspension_L std_gyro_z_above_suspension_R 0.9744789636560046
# std_gyro_x_below_suspension_L std_gyro_y_below_suspension_L 0.7759160176239249
# std_gyro_x_below_suspension_L std_gyro_x_below_suspension_R 0.8234527150743512
# std_gyro_x_below_suspension_L std_gyro_y_below_suspension_R 0.8801885640211244
# std_gyro_y_below_suspension_L std_gyro_z_below_suspension_L 0.7643590260255416
# std_gyro_y_below_suspension_L std_acc_x_dashboard_R 0.7944210395645893
# std_gyro_y_below_suspension_L std_acc_z_dashboard_R 0.7632648138285316
# std_gyro_y_below_suspension_L std_acc_z_below_suspension_R 0.782539719872123
# std_gyro_y_below_suspension_L std_gyro_y_dashboard_R 0.7826629734930387
# std_gyro_y_below_suspension_L std_gyro_x_below_suspension_R 0.7788674377052254
# std_gyro_y_below_suspension_L std_gyro_y_below_suspension_R 0.8329951600763621
# std_gyro_z_below_suspension_L std_acc_x_dashboard_R 0.8719027853885617
# std_gyro_z_below_suspension_L std_acc_y_dashboard_R 0.830236297991849
# std_gyro_z_below_suspension_L std_acc_y_below_suspension_R 0.7759965879819236
# std_gyro_z_below_suspension_L std_acc_z_below_suspension_R 0.8058507381298216
# std_gyro_z_below_suspension_L std_gyro_y_dashboard_R 0.847178588968477
# std_gyro_z_below_suspension_L std_gyro_z_below_suspension_R 0.909888835528546
# std_mag_x_dashboard_L std_mag_x_dashboard_R 0.9657802571829133
# std_mag_y_dashboard_L std_mag_y_dashboard_R 0.9378146262441126
# std_mag_z_dashboard_L std_mag_z_dashboard_R 0.7870099517944428
# std_acc_x_dashboard_R std_acc_y_dashboard_R 0.9023306502997696
# std_acc_x_dashboard_R std_acc_z_dashboard_R 0.8660992699065797
# std_acc_x_dashboard_R std_acc_x_above_suspension_R 0.7805593514548571
# std_acc_x_dashboard_R std_acc_y_above_suspension_R 0.7909308211013042
# std_acc_x_dashboard_R std_acc_z_above_suspension_R 0.8370425795603046
# std_acc_x_dashboard_R std_acc_x_below_suspension_R 0.8416535157119099
# std_acc_x_dashboard_R std_acc_y_below_suspension_R 0.8824639900861015
# std_acc_x_dashboard_R std_acc_z_below_suspension_R 0.7934744644489511
# std_acc_x_dashboard_R std_gyro_x_dashboard_R 0.7519140922647706
# std_acc_x_dashboard_R std_gyro_y_dashboard_R 0.9503021425366314
# std_acc_x_dashboard_R std_gyro_z_below_suspension_R 0.8881589850292917
# std_acc_y_dashboard_R std_acc_z_dashboard_R 0.9170172892837466
# std_acc_y_dashboard_R std_acc_x_above_suspension_R 0.8122535202316865
# std_acc_y_dashboard_R std_acc_y_above_suspension_R 0.8908279747768282
# std_acc_y_dashboard_R std_acc_z_above_suspension_R 0.8696166902469739
# std_acc_y_dashboard_R std_acc_x_below_suspension_R 0.881069833288968
# std_acc_y_dashboard_R std_acc_y_below_suspension_R 0.9437497321717605
# std_acc_y_dashboard_R std_gyro_x_dashboard_R 0.8351267646864651
# std_acc_y_dashboard_R std_gyro_y_dashboard_R 0.9490526665561512
# std_acc_y_dashboard_R std_gyro_z_below_suspension_R 0.8422574483183661
# std_acc_z_dashboard_R std_acc_x_above_suspension_R 0.8889776846095948
# std_acc_z_dashboard_R std_acc_y_above_suspension_R 0.9032768653189821
# std_acc_z_dashboard_R std_acc_z_above_suspension_R 0.949606386429206
# std_acc_z_dashboard_R std_acc_x_below_suspension_R 0.9253969289234577
# std_acc_z_dashboard_R std_acc_y_below_suspension_R 0.9291046984176908
# std_acc_z_dashboard_R std_gyro_x_dashboard_R 0.9100788042480882
# std_acc_z_dashboard_R std_gyro_y_dashboard_R 0.9085498264713168
# std_acc_x_above_suspension_R std_acc_y_above_suspension_R 0.9498319649932047
# std_acc_x_above_suspension_R std_acc_z_above_suspension_R 0.9405743658804167
# std_acc_x_above_suspension_R std_acc_x_below_suspension_R 0.8870860546471183
# std_acc_x_above_suspension_R std_acc_y_below_suspension_R 0.8494911741578054
# std_acc_x_above_suspension_R std_gyro_x_dashboard_R 0.918592569950436
# std_acc_x_above_suspension_R std_gyro_y_dashboard_R 0.7895295897018244
# std_acc_y_above_suspension_R std_acc_z_above_suspension_R 0.9492549987224993
# std_acc_y_above_suspension_R std_acc_x_below_suspension_R 0.8864143655454321
# std_acc_y_above_suspension_R std_acc_y_below_suspension_R 0.8861235924695826
# std_acc_y_above_suspension_R std_gyro_x_dashboard_R 0.925489083486985
# std_acc_y_above_suspension_R std_gyro_y_dashboard_R 0.8292973162202446
# std_acc_z_above_suspension_R std_acc_x_below_suspension_R 0.9126586913857783
# std_acc_z_above_suspension_R std_acc_y_below_suspension_R 0.8914453626164701
# std_acc_z_above_suspension_R std_gyro_x_dashboard_R 0.9295880140674982
# std_acc_z_above_suspension_R std_gyro_y_dashboard_R 0.8564718942658776
# std_acc_x_below_suspension_R std_acc_y_below_suspension_R 0.9512422294514045
# std_acc_x_below_suspension_R std_gyro_x_dashboard_R 0.8545857475313801
# std_acc_x_below_suspension_R std_gyro_y_dashboard_R 0.8711441133072729
# std_acc_y_below_suspension_R std_gyro_x_dashboard_R 0.8414389568998116
# std_acc_y_below_suspension_R std_gyro_y_dashboard_R 0.9113139323635666
# std_acc_y_below_suspension_R std_gyro_z_below_suspension_R 0.8235454434912043
# std_acc_z_below_suspension_R std_gyro_y_dashboard_R 0.7744324699241972
# std_acc_z_below_suspension_R std_gyro_y_below_suspension_R 0.8197094953394108
# std_acc_z_below_suspension_R std_gyro_z_below_suspension_R 0.8676135071914766
# std_gyro_x_dashboard_R std_gyro_y_dashboard_R 0.7940095926446894
# std_gyro_y_dashboard_R std_gyro_z_below_suspension_R 0.859454086929211
# std_gyro_z_dashboard_R std_gyro_z_above_suspension_R 0.9789349868159185
# std_gyro_x_above_suspension_R std_gyro_y_above_suspension_R 0.8285273420730251
# std_gyro_x_below_suspension_R std_gyro_y_below_suspension_R 0.9262207029432986
# std_temp_dashboard_R std_temp_above_suspension_R 0.9095617564286859
# std_temp_dashboard_R std_temp_below_suspension_R 0.9103003255075129
# std_temp_above_suspension_R std_temp_below_suspension_R 0.9464321927242031

# %% [markdown]
# Per togliere le feature inutili, ho dovuto analizzare tutte le coppie di features molto correlate, e scegliere arbitrariamente quali tenere.

# %%
# risultati della selezione:
all_avg_acc_z = [col for col in corr_matrix_df.columns if col[:9] == 'avg_acc_z']
all_std_mag = [col for col in corr_matrix_df.columns if col[:7] == 'std_mag' and not col[-11:] =='dashboard_R']


to_keep = ['avg_speed', 'avg_acc_x_dashboard_L', 'avg_acc_y_dashboard_L', *all_avg_acc_z, 'avg_gyro_x_dashboard_L', 'avg_gyro_y_dashboard_L', 'avg_gyro_z_dashboard_L',
            'avg_mag_z_dashboard_L', 'avg_temp_dashboard_L', 'avg_temp_above_suspension_L',
           'std_acc_z_dashboard_L', 'std_gyro_z_dashboard_L', *all_std_mag, 'std_temp_dashboard_L',
           'std_temp_above_suspension_L', 'std_temp_below_suspension_L']

# %%
corr_matrix_df.index = range(110)
corr_matrix_df = corr_matrix_df[to_keep].iloc[[list(corr_matrix_df.columns).index(el) for el in to_keep]]
corr_matrix_df.index = list(corr_matrix_df.columns)

# %%
# solo 29 feature rimaste
corr_matrix_df.shape
# Out:
# (29, 29)

# %% [markdown]
# ## correlation matrix finale

# %%
corr_matrix_df.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b38eb_row0_col0, #T_b38eb_row1_col1, #T_b38eb_row2_col2, #T_b38eb_row3_col3, #T_b38eb_row4_col4, #T_b38eb_row5_col5, #T_b38eb_row6_col6, #T_b38eb_row7_col7, #T_b38eb_row8_col8, #T_b38eb_row9_col9, #T_b38eb_row10_col10, #T_b38eb_row11_col11, #T_b38eb_row12_col12, #T_b38eb_row13_col13, #T_b38eb_row14_col14, #T_b38eb_row15_col15, #T_b38eb_row16_col16, #T_b38eb_row17_col17, #T_b38eb_row18_col18, #T_b38eb_row19_col19, #T_b38eb_row20_col20, #T_b38eb_row21_col21, #T_b38eb_row22_col22, #T_b38eb_row23_col23, #T_b38eb_row24_col24, #T_b38eb_row25_col25, #T_b38eb_row26_col26, #T_b38eb_row27_col27, #T_b38eb_row28_col28 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b38eb_row0_col1, #T_b38eb_row6_col23 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_b38eb_row0_col2, #T_b38eb_row1_col24, #T_b38eb_row4_col1, #T_b38eb_row6_col20, #T_b38eb_row8_col14, #T_b38eb_row10_col20, #T_b38eb_row15_col20, #T_b38eb_row21_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_b38eb_row0_
{
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_b38eb_row1_col15, #T_b38eb_row3_col10, #T_b38eb_row3_col14, #T_b38eb_row3_col26, #T_b38eb_row4_col26, #T_b38eb_row8_col17, #T_b38eb_row13_col22, #T_b38eb_row16_col6, #T_b38eb_row25_col20, #T_b38eb_row27_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_b38eb_row1_col16, #T_b38eb_row4_col17, #T_b38eb_row5_col28, #T_b38eb_row13_col14, #T_b38eb_row22_col20, #T_b38eb_row26_col17, #T_b38eb_row26_col18 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_b38eb_row1_col18 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b38eb_row1_col19, #T_b38eb_row3_col19, #T_b38eb_row6_col14, #T_b38eb_row6_col15, #T_b38eb_row14_col28, #T_b38eb_row15_col8, #T_b38eb_row17_col0, #T_b38eb_row18_col28, #T_b38eb_row26_col19, #T_b38eb_row26_col27, #T_b38eb_row27_col15 {

# %% [markdown]
# ### Commenti aggiuntivi
#
# Ho selezionato aribitrariamente le features da rimuovere, non ho fatto uno script automatico perchè non mi è venuta in mente nessuna euristica per decidere quale tenere tra un gruppo di feature correlate. Questo motiva il fatto che questa parte del notebook abbia un codice abbastanza "sporco" e poco parametrico.
#
# Vista la naturale ridondanza tra queste feature, mi sembra improbabile che sia stata rimossa qualche feature importante.
#
# Sono rimaste solo 29 feature nel dataset, adesso nessuna coppia di features ha una correlazione lineare maggiore di 0.75.

# %% [markdown]
# ## Final Data Processing

# %% [markdown]
# Ora che ho una lista delle feature da tenere posso selezionarle da ogni dataset PVS

# %%
to_keep = ['road_condition','avg_longitude','avg_latitude'] + to_keep

# %%
dataset = {name:get_structural_features(data).select(to_keep) for name,data in dataset.items()}

# %%
dataset['PVS3'].show(5)
# Out:
# +--------------+-------------------+-------------------+--------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+---------------------+----------------------------+----------------------------+----------------------+----------------------+----------------------+---------------------+--------------------+---------------------------+---------------------+----------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+--------------------+---------------------------+---------------------------+
# |road_condition|      avg_longitude|       avg_latitude|           avg_speed|avg_acc_x_dashboard_L|avg_acc_y_dashboard_L|avg_acc_z_dashboard_L|avg_acc_z_above_suspension_L|avg_acc_z_below_suspension_L|avg_acc_z_dashboard_R|avg_acc_z_above_suspension_R|avg_acc_z_below_suspension_R|avg_gyro_x_dashboard_L|avg_gyro_y_dashboard_L|avg_gyro_z_dashboard_L|avg_mag_z_dashboard_L|avg_temp_dashboard_L|avg_temp_above_suspension_L|std_acc_z_dashboard_L|std_gyro_z_dashboard_L|std_mag_x_dashboard_L|std_mag_y_dashboard_L|std_mag_z_dashboard_L|std_mag_x_above_suspension_L|std_mag_y_above_suspension_L|std_mag_z_above_suspension_L|std_mag_x_above_suspension_R|std_mag_y_above_suspension_R|std_mag_z_above_suspension_R|std_temp_dashboard_L|std_temp_above_suspension_L|std_temp_below_suspension_L|
# +--------------+-------------------+-------------------+--------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+---------------------+----------------------------+----------------------------+----------------------+----------------------+----------------------+---------------------+--------------------+---------------------------+---------------------+----------------------+---------------------+---------------------+---------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+----------------------------+--------------------+---------------------------+---------------------------+
# |          good| -51.09903663474331|-27.717713525681596|0.007072364442786075| -0.00891393438994...| -5.04152165502598...|    9.811796342424223|           9.795506982808476|           9.795083981034777|    9.794797379901684|           9.738401452833727|           9.792965195364634|    0.0734424116599619|  -0.03933503260066...|  -0.03995753046291978| -0.18487670070035814|   32.49146888434999|          43.56736803000899|  0.03300266518334684|   0.12717764760489395|   0.6956155452929411|   0.5813017090271821|   0.6190308801542733|          1.5497308464194444|          1.5104397232055904|          0.7793665790782204|            4.03667897962121|           3.515801366256739|            4.61275932933596| 0.11191414949648705|        0.11210197414776023|        0.17803830071527832|
